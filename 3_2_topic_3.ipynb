# %%
import numpy as np
import matplotlib.pyplot as plt


def polar_circle(r):
    phi = np.linspace(0, 2 * np.pi, 200)
    rad = np.linspace(r, r, 200)
    plt.polar(phi, rad, color="red")
    plt.show()


polar_circle(1)
