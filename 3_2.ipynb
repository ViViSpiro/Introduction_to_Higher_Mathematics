# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

x_0 = 0.0
y_0 = 0.0
r_x = 2.0
r_y = 1.5

t = np.linspace(0, 2 * pi, 100)
plt.plot(x_0 + r_x * np.cos(t), y_0 + r_y * np.sin(t))
plt.grid(color="lightgray", linestyle="--")
plt.show()
